# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
#string
countries = ['India','USA','Canada','Australia','Russia']
pd.Series(countries)
# Out:
# 0        India
# 1          USA
# 2       Canada
# 3    Australia
# 4       Russia
# dtype: object

# %%
#int
runs = [23,45,67,87,12]
pd.Series(runs)
# Out:
# 0    23
# 1    45
# 2    67
# 3    87
# 4    12
# dtype: int64

# %%
#custom index
marks = [67,56,89,90,100]
subject = ['Maths','English','Science','SST','Hindi']
pd.Series(marks,index = subject)
# Out:
# Maths       67
# English     56
# Science     89
# SST         90
# Hindi      100
# dtype: int64

# %%
#setting a name
marks = pd.Series(marks, index = subject,name = 'marks of inder')
marks
# Out:
# Maths       67
# English     56
# Science     89
# SST         90
# Hindi      100
# Name: marks of inder, dtype: int64

# %%
#series from dict
marks = {
    'maths':67,
    'English':56,
    'science':89,
    'hindi': 100
}
marks_series = pd.Series(marks,name = 'marks of inder')
marks_series
# Out:
# maths       67
# English     56
# science     89
# hindi      100
# Name: marks of inder, dtype: int64

# %%
#series of attribute
#size
marks_series.size
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'marks of inder'

# %%
#is_unique
marks_series.is_unique
pd.Series([1,1,2,3,4,4]).is_unique
# Out:
# False

# %%
#index
marks_series.index
# Out:
# Index(['maths', 'English', 'science', 'hindi'], dtype='object')

# %%
#values
type(marks_series.values)
# Out:
# numpy.ndarray

# %%
#series using read_csv
#with one col

# pd.read_csv('/csv/subs.csv',squeeze = True)

# df = pd.read_csv('subs.csv')
# series = df['Subscribers gained']
# series

subs = pd.read_csv('subs.csv', usecols=['Subscribers gained']).squeeze()

# Display the Series
print(subs)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#with two col
# s = pd.read_csv('bollywood.csv', usecols=['lead']).squeeze()
# s

s= pd.read_csv('bollywood.csv', index_col ='movie')['lead']
s
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
#head and tail

# s.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
#series indexing

x = pd.Series([1,2,3,5,7,9])
x[2]

#negative indexing won't work
# Out:
# 3

# %%
'Alia Bhatt' in s.values
# Out:
# False

# %%
#plotting

subs.plot()
# Out:
# <Axes: >

# %%
s.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
######DATAFRAMES################

# %%
#using list
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]
pd.DataFrame(student_data, columns = ['IQ','marks','package'])
# Out:
#     IQ  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
#dicts
student_data = {
    'IQ':[100,90,120,80],
    'marks':[80,70,100,50],
    'package':[10,7,14,2]
}

pd.DataFrame(student_data)
# Out:
#     IQ  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
movies = pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#dataframe attributes and methods

#shape
movies.shape
ipl.shape
# Out:
# (950, 20)

# %%
#dtypes
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
#index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
#columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
#values
student_data.values
# Out:
# <function dict.values>

# %%
#head & tail

# movies.head()
movies.tail()
# Out:
#                     title_x     imdb_id  \
# 1624  Tera Mera Saath Rahen   tt0301250
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1626        Sabse Bada Sukh   tt0069204
# 1627                  Daaka  tt10833860
# 1628               Humsafar   tt2403201
#
#                                             poster_path  \
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
# ...

# %%
#sample
movies.sample()
# Out:
#                title_x    imdb_id poster_path  \
# 1520  Ghaav: The Wound  tt0391187         NaN
#
#                                            wiki_link           title_y  \
# 1520  https://en.wikipedia.org/wiki/Ghaav:_The_Wound  Ghaav: The Wound
#
#         original_title  is_adult  year_of_release runtime              genres  \
# 1520  Ghaav: The Wound         0             2002      \N  Action|Crime|Drama
#
#       imdb_rating  imdb_votes  \
# 1520          6.5          11
#
#                                                   story  \
# 1520  Jogi Thakur (Govind Namdev) is the power behin...
#
#                                                 summary tagline  \
# 1520  Jogi Thakur (Govind Namdev) is the power behin...     NaN
#
#                                                  actors wins_nominations  \
# 1520  Pankaj Berry|Rahul Bhat|Seema Biswas|Gayatri|G...              NaN
#
#      release_date
# 1520          NaN

# %%
#info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#duplicated
movies.duplicated().sum()
# Out:
# 0

# %%
#rename
student_data
# Out:
# {'IQ': [100, 90, 120, 80],
#  'marks': [80, 70, 100, 50],
#  'package': [10, 7, 14, 2]}

# %%
# student_data.rename(columns={'marks':'percentage','package':'LPA'},inplace = True)
student_data.rename(columns={'marks': 'percentage', 'package': 'LPA'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 2
#       1 # student_data.rename(columns={'marks':'percentage','package':'LPA'},inplace = True)
# ----> 2 student_data.rename(columns={'marks': 'percentage', 'package': 'LPA'}, inplace=True)
#
# AttributeError: 'dict' object has no attribute 'rename'

# %%
#DataFrame Functions
mark = pd.DataFrame([
    [100,80,10],
    [120,70,14],
    [90,60,10],
    [100,65,12]
],columns =['IQ', 'marks', 'Package'])

mark.value_counts()
# Out:
# IQ   marks  Package
# 90   60     10         1
# 100  65     12         1
#      80     10         1
# 120  70     14         1
# Name: count, dtype: int64

# %%
7
